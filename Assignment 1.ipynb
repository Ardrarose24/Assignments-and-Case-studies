# %% [markdown]
# ASSIGNMENT 1: Assignment on Python for Data Science

# %%
#To start with the assignment, we import all the necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Read the dataset to python environment.

# %%
data = pd.read_excel(r"C:\Users\ALFRED\Desktop\iris.xls")

# %%
data  #the given data is displayed here.
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
data.mean()
# Out:
# C:\Users\ALFRED\AppData\Local\Temp\ipykernel_8652\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
data.isna().sum() #here we get the total number of null values in each column.
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# Bar Graph:

# %%
plt.bar(data['Classification'],data['SL'])
plt.title('Classification vs SL')
plt.xlabel('Classification')
plt.ylabel('SL')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['Classification'],data['SW'],color = 'y')
plt.title('Classification vs SW')
plt.xlabel('Classification')
plt.ylabel('SW')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['Classification'],data['PL'],color = 'g')
plt.title('Classification vs PL')
plt.xlabel('Classification')
plt.ylabel('PL')
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['Classification'],data['PW'], color = 'orange')
plt.title('Classification vs PW')
plt.xlabel('Classification')
plt.ylabel('PW')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Scatter plots:

# %%
plt.scatter(data['PL'],data['PW'],s=30,marker = '*', color='purple')
plt.show()

# %%
plt.scatter(data['SL'],data['SW'],s=30,marker = '*', color='purple')
plt.show()

# %%
plt.scatter(data['SW'],data['PL'],s=20,marker = '^', color='brown')
plt.show()

# %% [markdown]
# Pair plot:

# %%
sns.pairplot(data)

# %% [markdown]
# Heat map:

# %%
data1 = data[['SL','SW','PL','PW']]
sns.heatmap(data1.corr(),annot = True)
# Out:
# <Axes: >
