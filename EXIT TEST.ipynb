# %%
import pandas as pd 
import numpy as np                     # For mathematical calculations 
import seaborn as sns                  # For data visualization 
import matplotlib.pyplot as plt        # For plotting graphs 
# %matplotlib inline 
import warnings                        # To ignore any warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\ALFRED\Downloads\train (1).csv")  #loading the dataset

# %%
df1 = df.copy()

# %%
df.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %% [markdown]
# Knowing necessary details and EDA

# %%
df.shape
# Out:
# (13994, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13975 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13577 non-null  object
#  7   ball_controlling_skills    13581 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13970 non-null  float64
#  11  penalties_conversion_rate  13964 non-null  float64
#  12  mental_strength            13966 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                              count       mean        std    min   25%   50%  \
# age                        13994.0  21.135844   5.162719   16.0  17.0  20.0
# ball_controlling_skills    13581.0  56.043958  16.787353    5.0  51.0  61.0
# body_reflexes              13994.0  61.934329  14.931963   12.0  54.0  64.0
# body_balance               13994.0  62.753323  14.203638    9.0  55.0  65.0
# jumping_skills             13970.0  63.612026  11.938712   14.0  57.0  64.0
# penalties_conversion_rate  13964.0  48.495703  15.767506    7.0  39.0  49.0
# mental_strength            13966.0  56.768366  11.977744    9.0  49.0  58.0
# goalkeeping_skills         13994.0  16.474632  16.874551    1.0  10.0  11.0
# defending_skills           13994.0  48.108118  16.821929    9.0  36.0  52.0
# passing_skills             13994.0  52.935973  14.201782   13.0  45.0  56.0
# dribbling_skills           13994.0  28.536730   9.735249    2.0  25.0  31.0
# ...

# %%
df = df.drop(['player_id', 'name'], axis = 1) # Dropping unwanted columns

# %%
df.shape
# Out:
# (13994, 28)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
df['selection'].value_counts()
# Out:
# 1    7802
# 0    6192
# Name: selection, dtype: int64

# %%
df['selection'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# Function to plot the distribution of numerical variable
def plot_num_var(var_name, var_label, bin_num):
    plt.figure(figsize = (25,5))
    plt.suptitle('Distribution of {}'.format(var_name))
    plt.subplot(1,2,1)
    sns.histplot(data=df, x=var_name, bins=bin_num)
  #plt.title('Fig {}(a)'.format(fig_num))
    plt.xlabel(var_name)
    plt.ylabel('Count')

    plt.subplot(1,2,2)
    sns.boxplot(data=df, x=var_name)
 # plt.title('Fig {}(b)'.format(fig_num))
    plt.xlabel(var_name)
  
    plt.show()

# %%
# Function to plot the distribution of numerical variable by selection status
def plot_numvar_selection(var_name, var_label, bin_num):
    plt.figure(figsize = (25,5))
    plt.suptitle('Distribution of {} by Selection Status'.format(var_name))
    plt.subplot(1,2,1)
    sns.histplot(data=df, x=var_name, hue='selection', bins=bin_num)
 # plt.title('Fig {}(a)'.format(fig_num))
    plt.xlabel(var_label)
    plt.ylabel('Count')
  
    plt.subplot(1,2,2)
    sns.boxplot(data=df, x='selection', y=var_name)
  #plt.title('Fig {}(b)'.format(fig_num))
    plt.xlabel('selection status')
  
    plt.show()

# %%
# Distribution of ball controlling skills of the players
plot_num_var('ball_controlling_skills', 'selection', 30)
# Distribution of ball controlling skills of the players by selection
plot_numvar_selection('ball_controlling_skills', 'selection', 30)

# %%
# Distribution of age of the players
plot_num_var('age', 'selection', 30)
# Distribution of age of the players by selection
plot_numvar_selection('age', 'selection', 30)

# %%
# Distribution of body reflexes of the players
plot_num_var('body_reflexes', 'selection', 30)
# Distribution of body reflexes of the players by selection
plot_numvar_selection('body_reflexes', 'selection', 30)

# %%
# Distribution of body balance of the players
plot_num_var('body_balance', 'selection', 30)
# Distribution of body balance of the players by selection
plot_numvar_selection('body_balance', 'selection', 30)

# %%
# Distribution of jumping skills of the players
plot_num_var('jumping_skills', 'selection', 30)
# Distribution of jumping skills of the players by selection
plot_numvar_selection('jumping_skills', 'selection', 30)

# %%
# Distribution of penalties conversion rate of the players
plot_num_var('penalties_conversion_rate', 'selection', 30)
# Distribution of penalties conversion rate of the players by selection
plot_numvar_selection('penalties_conversion_rate', 'selection', 30)

# %%
# Distribution of mental_strength of the players
plot_num_var('mental_strength', 'selection', 30)
# Distribution of mental_strength of the players by selection
plot_numvar_selection('mental_strength', 'selection', 30)

# %%
# Distribution of goalkeeping_skills of the players
plot_num_var('goalkeeping_skills', 'selection', 30)
# Distribution of goalkeeping_skills of the players by selection
plot_numvar_selection('goalkeeping_skills', 'selection', 30)

# %%
# Distribution of defending_skills of the players
plot_num_var('defending_skills', 'selection', 30)
# Distribution of defending_skills of the players by selection
plot_numvar_selection('defending_skills', 'selection', 30)

# %%
# Distribution of passing_skills of the players
plot_num_var('passing_skills', 'selection', 30)
# Distribution of passing_skills of the players by selection
plot_numvar_selection('passing_skills', 'selection', 30)

# %%
# Distribution of dribbling_skills of the players
plot_num_var('dribbling_skills', 'selection', 30)
# Distribution of dribbling_skills of the players by selection
plot_numvar_selection('dribbling_skills', 'selection', 30)

# %%
# Distribution of shot_accuracy of the players
plot_num_var('shot_accuracy', 'selection', 30)
# Distribution of shot_accuracy of the players by selection
plot_numvar_selection('shot_accuracy', 'selection', 30)

# %%
# Distribution of body_strength_stamina of the players
plot_num_var('body_strength_stamina', 'selection', 30)
# Distribution of body_strength_stamina of the players by selection
plot_numvar_selection('body_strength_stamina', 'selection', 30)

# %%
# Distribution of max_running_speed of the players
plot_num_var('max_running_speed', 'selection', 30)
# Distribution of max_running_speed of the players by selection
plot_numvar_selection('max_running_speed', 'selection', 30)

# %%
# Distribution of behaviour_rating of the players
plot_num_var('behaviour_rating', 'selection', 30)
# Distribution of behaviour_rating of the players by selection
plot_numvar_selection('behaviour_rating', 'selection', 30)

# %%
# Distribution of matches_played of the players
plot_num_var('matches_played', 'selection', 30)
# Distribution of matches_played of the players by selection
plot_numvar_selection('matches_played', 'selection', 30)

# %%
# Distribution of fitness_rating of the players
plot_num_var('fitness_rating', 'selection', 30)
# Distribution of fitness_rating of the players by selection
plot_numvar_selection('fitness_rating', 'selection', 30)

# %%
# Distribution of trophies_won of the players
plot_num_var('trophies_won', 'selection', 30)
# Distribution of trophies_won of the players by selection
plot_numvar_selection('trophies_won', 'selection', 30)

# %%
# Distribution of years_of_experience of the players
plot_num_var('years_of_experience', 'selection', 30)
# Distribution of years_of_experience of the players by selection
plot_numvar_selection('years_of_experience', 'selection', 30)

# %%
# Distribution of no_of_disqualifications of the players
plot_num_var('no_of_disqualifications', 'selection', 30)
# Distribution of no_of_disqualifications of the players by selection
plot_numvar_selection('no_of_disqualifications', 'selection', 30)

# %%
df["height"] = df["height"].apply(lambda x: int(x.split("'")[0]) * 12 + int(x.split("'")[1]))
df["weight"] = df["weight"].str.extract("(\d+)").astype(float)
# Converting height and weight from object to float and int
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df["height"] = df["height"].apply(lambda x: int(x.split("'")[0]) * 12 + int(x.split("'")[1]))
#       2 df["weight"] = df["weight"].str.extract("(\d+)").astype(float)
#
# File ~\Anaconda\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\Anaconda\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
# ...

# %%
df.dtypes
# Out:
# age                            int64
# gender                        object
# country                       object
# height                         int64
# weight                       float64
# ball_controlling_skills      float64
# body_reflexes                float64
# body_balance                 float64
# jumping_skills               float64
# penalties_conversion_rate    float64
# mental_strength              float64
# goalkeeping_skills           float64
# defending_skills             float64
# passing_skills               float64
# dribbling_skills             float64
# shot_accuracy                float64
# body_strength_stamina        float64
# max_running_speed            float64
# strong_foot                   object
# behaviour_rating             float64
# matches_played               float64
# fitness_rating               float64
# trophies_won                 float64
# dedication_level              object
# coaching                      object
# ...

# %%
# Distribution of height of the players
plot_num_var('height', 'selection', 30)
# Distribution of height of the players by selection
plot_numvar_selection('height', 'selection', 30)

# %%
# Distribution of weight of the players
plot_num_var('weight', 'selection', 30)
# Distribution of weight of the players by selection
plot_numvar_selection('weight', 'selection', 30)

# %% [markdown]
# #analysing categorical columns

# %%
df['gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 2

# %%
fig,ax = plt.subplots(figsize=(15,5))
ax=sns.countplot(x='gender', data=df)
plt.title(' Distribution of the different genders')
plt.show()

# %%
df['country'].nunique()
# Out:
# 163

# %%
df['strong_foot'].unique()
# Out:
# array(['Right', 'Any', 'Left', 'None', nan], dtype=object)

# %%
fig,ax = plt.subplots(figsize=(15,5))
ax=sns.countplot(x='strong_foot', data=df)
plt.title('Distribution of the strong foot of the player')
plt.show()

# %%
df['dedication_level'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
fig,ax = plt.subplots(figsize=(15,5))
ax=sns.countplot(x='dedication_level', data=df)
plt.title('Distribution of the dedication level of the player')
plt.show()

# %%
df['coaching'].unique()
# Out:
# array(['Talent Hunt', 'Source', 'Academy', 'Unknown', nan], dtype=object)

# %%
fig,ax = plt.subplots(figsize=(15,5))
ax=sns.countplot(x='coaching', data=df)
plt.title('Distribution of the coaching the player got')
plt.show()

# %%
df.isna().sum() # Finding and solving missing values
# Out:
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                       417
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                  552
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                     125
# years_of_experience          144
# no_of_disqualifications        0
# selection                      0
# dtype: int64

# %%
freqgraph = df.select_dtypes(include=['float','int64'])
freqgraph.hist(figsize = (20,15))
plt.show()

# %%
df['gender'].fillna(df['gender'].mode()[0], inplace = True)
df['strong_foot'].fillna(df['strong_foot'].mode()[0], inplace = True)
df['coaching'].fillna(df['coaching'].mode()[0], inplace = True)

# %%
df['matches_played'].fillna(df['matches_played'].median(), inplace = True)
df['fitness_rating'].fillna(df['fitness_rating'].median(), inplace = True)
df['years_of_experience'].fillna(df['years_of_experience'].median(), inplace = True)

# %%
df['weight'] = df['weight'].fillna(df['weight'].mean())
df['ball_controlling_skills'] = df['ball_controlling_skills'].fillna(df['ball_controlling_skills'].mean())
df['penalties_conversion_rate'] = df['penalties_conversion_rate'].fillna(df['penalties_conversion_rate'].mean())
df['jumping_skills'] = df['jumping_skills'].fillna(df['jumping_skills'].mean())
df['mental_strength'] = df['mental_strength'].fillna(df['mental_strength'].mean())
df['shot_accuracy'] = df['shot_accuracy'].fillna(df['shot_accuracy'].mean())
df['behaviour_rating'] = df['behaviour_rating'].fillna(df['behaviour_rating'].mean())

# %%
df.isna().sum()
# Out:
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# shot_accuracy                0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# selection                    0
# dtype: int64

# %%
for i in df.columns:                # Finding and solving outliers
    if df[i].dtype == float:
        plt.figure()
        sns.boxplot(df[i])
        plt.title(i)
        plt.show()

# %%
num_col = ['age', 'height']
for i in num_col:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(i)

# %%
outlier_columns = ['age','height','weight','ball_controlling_skills','body_reflexes','body_balance','jumping_skills',
                   'penalties_conversion_rate','mental_strength','goalkeeping_skills','passing_skills','dribbling_skills',
                   'shot_accuracy', 'body_strength_stamina','max_running_speed','behaviour_rating','matches_played',
                   'fitness_rating','years_of_experience','no_of_disqualifications']

# %%
for i in outlier_columns:
    
    Q1 = np.percentile(df[i], 25, interpolation = 'midpoint')
    Q2 = np.percentile(df[i], 50, interpolation = 'midpoint')
    Q3 = np.percentile(df[i], 75, interpolation = 'midpoint')
   
    
    IQR = Q3 - Q1
    
    
    up_lim = Q3+1.5*IQR
    low_lim = Q1 - 1.5*IQR
    
    
    outliers = []
    for x in df[i]:
        if(x>up_lim) or (x<low_lim):
            outliers.append(x)
            
    df[i] = np.where(df[i]>up_lim,up_lim,np.where(df[i]<low_lim,low_lim,df[i]))

# %%
for i in outlier_columns:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(i)

# %%
df = pd.get_dummies(df)  # encoding

# %%
df.shape
# Out:
# (13994, 199)

# %%
#splitting data to feature and target


x = df.drop(['selection'], axis = 1)
y = df['selection']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression()
logit_model.fit(x_train, y_train)
y_pred_lr = logit_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
print('Accuracy = ',accuracy_score(y_test,y_pred_lr))
print('precision = ',precision_score(y_test,y_pred_lr))
print('Recall = ',recall_score(y_test,y_pred_lr))
print('f1 score =',f1_score(y_test,y_pred_lr))
# Out:
# Accuracy =  0.7413361914969632
# precision =  0.7389460932768019
# Recall =  0.806345009914078
# f1 score = 0.7711757269279393

# %%
confusion_matrix(y_test,y_pred_lr)
# Out:
# array([[ 855,  431],
#        [ 293, 1220]], dtype=int64)

# %%
#kNN
from sklearn.neighbors import KNeighborsClassifier
metric = []
neighbors = np.arange(3,15)

for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors = k, metric = 'minkowski',p=2)
    classifier.fit(x_train,y_train)
    y_pred_knn = classifier.predict(x_test)
    acc = accuracy_score(y_test,y_pred_knn)
    metric.append(acc)

# %%
plt.plot(neighbors,metric,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
classifier = KNeighborsClassifier(n_neighbors = 14, metric = 'minkowski',p=2)
classifier.fit(x_train,y_train)
y_pred_knn = classifier.predict(x_test)

# %%
print('Accuracy = ',accuracy_score(y_test,y_pred_knn))
print('precision = ',precision_score(y_test,y_pred_knn))
print('Recall = ',recall_score(y_test,y_pred_knn))
print('f1 score =',f1_score(y_test,y_pred_knn))
# Out:
# Accuracy =  0.76670239371204
# precision =  0.7843915343915344
# Recall =  0.7838730998017185
# f1 score = 0.7841322314049588

# %%
confusion_matrix(y_test,y_pred_knn)
# Out:
# array([[ 960,  326],
#        [ 327, 1186]], dtype=int64)

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt_clf = DecisionTreeClassifier()
dt_clf.fit(x_train,y_train)
y_pred = dt_clf.predict(x_test)

# %%
print('Accuracy;', accuracy_score(y_test,y_pred))
# Out:
# Accuracy; 0.774205073240443

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 943  343]
#  [ 289 1224]]

# %%
#Randoom forest
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier()
rf_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_clf.predict(x_test)

# %%
print('Accuracy is;', accuracy_score(y_test,y_pred))
# Out:
# Accuracy is; 0.8453018935334048

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1044  242]
#  [ 191 1322]]

# %% [markdown]
# So, from the accuracy score, the best model is random forest with an accuracy of 84%
